# %%
import requests

# send api request
res = requests.post('http://43.206.182.42:8080/getAllProjects')
arr = res.json()['project_list']
l = list(map(lambda x: len(x['codes']), arr))
arr[0]
# Out:
# {'_id': '644e286830bc1ce8ee432a0e',
#  'projectId': 1,
#  'name': 'BiSwap LP',
#  'types': ['Decentralized Exchange (DEX)', 'Decentralized Finance (DeFi)'],
#  'tags': ['dex', 'defi'],
#  'description': 'BiSwap is a decentralized exchange platform on the Binance Smart Chain network. Our platform features a three-level referral system and low transaction fees (0.1%). Our mission is to become a leading platform for token swaps in the DeFi space by offering fast, secure, and easy-to-use services.',
#  'supportingMaterials': [{'type': 'whitepaper',
#    'format': 'pdf',
#    'url': 'https://example.com/whitepaper.pdf'},
#   {'type': 'documentation',
#    'format': 'html',
#    'url': 'https://example.com/documentation'}],
#  'codeSimilarity': [{'project': 'Uniswap', 'similarity': 63},
#   {'project': 'PancakeSwap', 'similarity': 49},
#   {'project': 'ParaSwap', 'similarity': 29}],
#  'icon': 'data:image/jpeg;base64,...',
#  'codes': [{'fileName': 'BSWToken.sol',
# ...
